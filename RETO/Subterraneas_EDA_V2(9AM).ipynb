# %%
! pip install geopandas qeds -q

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\karin\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: scipy in c:\users\karin\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\karin\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: seaborn in c:\users\karin\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: numpy in c:\users\karin\anaconda3\lib\site-packages (from missingno) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\karin\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\karin\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karin\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\karin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#cargamos las librerías

# Para omitir los mensajes de warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import time
from collections import Counter

import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline
# activate plot theme
import qeds
qeds.themes.mpl_style();

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Carga de datos

# %%
#la ruta donde se encuentra el archivo
subterranea="https://raw.githubusercontent.com/PosgradoMNA/actividades-del-projecto-equipo_37/main/RETO/Datos_de_calidad_del_agua_de_sitios_de_monitoreo_de_aguas_subterraneas_2020.csv"
df_sub = pd.read_csv(subterranea, encoding='cp1252')
df_sub.columns
# Out:
# Index(['CLAVE', 'SITIO', 'ORGANISMO_DE_CUENCA', 'ESTADO', 'MUNICIPIO',
#        'ACUIFERO', 'SUBTIPO', 'LONGITUD', 'LATITUD', 'PERIODO', 'ALC_mg/L',
#        'CALIDAD_ALC', 'CONDUCT_mS/cm', 'CALIDAD_CONDUC', 'SDT_mg/L',
#        'SDT_M_mg/L', 'CALIDAD_SDT_ra', 'CALIDAD_SDT_salin', 'FLUORUROS_mg/L',
#        'CALIDAD_FLUO', 'DUR_mg/L', 'CALIDAD_DUR', 'COLI_FEC_NMP/100_mL',
#        'CALIDAD_COLI_FEC', 'N_NO3_mg/L', 'CALIDAD_N_NO3', 'AS_TOT_mg/L',
#        'CALIDAD_AS', 'CD_TOT_mg/L', 'CALIDAD_CD', 'CR_TOT_mg/L', 'CALIDAD_CR',
#        'HG_TOT_mg/L', 'CALIDAD_HG', 'PB_TOT_mg/L', 'CALIDAD_PB', 'MN_TOT_mg/L',
#        'CALIDAD_MN', 'FE_TOT_mg/L', 'CALIDAD_FE', 'SEMAFORO', 'CONTAMINANTES',
#        'CUMPLE_CON_ALC', 'CUMPLE_CON_COND', 'CUMPLE_CON_SDT_ra',
#        'CUMPLE_CON_SDT_salin', 'CUMPLE_CON_FLUO', 'CUMPLE_CON_DUR',
#        'CUMPLE_CON_CF', 'CUMPLE_CON_NO3', 'CUMPLE_CON_AS', 'CUMPLE_CON_CD',
#        'CUMPLE_CON_CR', 'CUMPLE_CON_HG', 'CUMPLE_CON_PB', 'CUMPLE_CON_MN',
#        'CUMPLE_CON_FE'],
#       dtype='object')

# %%
#vamos a ver el tamaño de la base de datos
df_sub.shape
# Out:
# (1068, 57)

# %%
#vamos a ver el tipo de datos que tenemos por columna
df_sub.dtypes
# Out:
# CLAVE                    object
# SITIO                    object
# ORGANISMO_DE_CUENCA      object
# ESTADO                   object
# MUNICIPIO                object
# ACUIFERO                 object
# SUBTIPO                  object
# LONGITUD                float64
# LATITUD                 float64
# PERIODO                   int64
# ALC_mg/L                float64
# CALIDAD_ALC              object
# CONDUCT_mS/cm           float64
# CALIDAD_CONDUC           object
# SDT_mg/L                float64
# SDT_M_mg/L               object
# CALIDAD_SDT_ra           object
# CALIDAD_SDT_salin        object
# FLUORUROS_mg/L           object
# CALIDAD_FLUO             object
# DUR_mg/L                 object
# CALIDAD_DUR              object
# COLI_FEC_NMP/100_mL      object
# CALIDAD_COLI_FEC         object
# N_NO3_mg/L               object
# CALIDAD_N_NO3            object
# AS_TOT_mg/L              object
# CALIDAD_AS               object
# CD_TOT_mg/L              object
# CALIDAD_CD               object
# CR_TOT_mg/L              object
# CALIDAD_CR               object
# HG_TOT_mg/L              object
# CALIDAD_HG               object
# PB_TOT_mg/L              object
# CALIDAD_PB               object
# MN_TOT_mg/L              object
# CALIDAD_MN               object
# FE_TOT_mg/L              object
# CALIDAD_FE               object
# SEMAFORO                 object
# CONTAMINANTES            object
# CUMPLE_CON_ALC           object
# CUMPLE_CON_COND          object
# CUMPLE_CON_SDT_ra        object
# CUMPLE_CON_SDT_salin     object
# CUMPLE_CON_FLUO          object
# CUMPLE_CON_DUR           object
# CUMPLE_CON_CF            object
# CUMPLE_CON_NO3           object
# CUMPLE_CON_AS            object
# CUMPLE_CON_CD            object
# CUMPLE_CON_CR            object
# CUMPLE_CON_HG            object
# CUMPLE_CON_PB            object
# CUMPLE_CON_MN            object
# CUMPLE_CON_FE            object
# dtype: object

# %%
for colum in list(df_sub.columns):
  
  try:
    df_sub[colum] = df_sub[colum].str.replace('<', '', regex=True) #Reemplazar valores con <
    df_sub[colum] = df_sub[colum].str.replace('=', '', regex=True) #Reemplazar valores con =

    try:
      df_sub[colum] = df_sub[colum].astype(float) #Convertir columas a flotantes
      
    except:
      pass

  except:
    pass

  df_sub[colum] = pd.to_numeric(df_sub[colum], errors='coerce').fillna(df_sub[colum]) #Convertir columas a Numericos

df_sub.head(10).T
# Out:
#                                             0                        1  \
# CLAVE                                  DLAGU6                DLAGU6516
# SITIO                            POZO SAN GIL   POZO R013 CAÑADA HONDA
# ORGANISMO_DE_CUENCA   LERMA SANTIAGO PACIFICO  LERMA SANTIAGO PACIFICO
# ESTADO                         AGUASCALIENTES           AGUASCALIENTES
# MUNICIPIO                            ASIENTOS           AGUASCALIENTES
# ACUIFERO                   VALLE DE CHICALOTE       VALLE DE CHICALOTE
# SUBTIPO                                  POZO                     POZO
# LONGITUD                            -102.0221               -102.20075
# LATITUD                              22.20887                 21.99958
# PERIODO                                  2020                     2020
# ALC_mg/L                               229.99                   231.99
# CALIDAD_ALC                              Alta                     Alta
# CONDUCT_mS/cm                           940.0                    608.0
# CALIDAD_CONDUC          Permisible para riego         Buena para riego
# SDT_mg/L                                  NaN                      NaN
# SDT_M_mg/L                              603.6                    445.4
# CALIDAD_SDT_ra             Cultivos sensibles     Excelente para riego
# CALIDAD_SDT_salin             Potable - Dulce          Potable - Dulce
# FLUORUROS_mg/L                         0.9766                   0.9298
# CALIDAD_FLUO                 Potable - Optima         Potable - Optima
# DUR_mg/L                              213.732                 185.0514
# CALIDAD_DUR                    Potable - Dura           Potable - Dura
# COLI_FEC_NMP/100_mL                       1.1                      1.1
# CALIDAD_COLI_FEC          Potable - Excelente      Potable - Excelente
# N_NO3_mg/L                           4.184656                  5.75011
# CALIDAD_N_NO3             Potable - Excelente  Potable - Buena calidad
# AS_TOT_mg/L                            0.0161                   0.0134
# CALIDAD_AS                     Apta como FAAP           Apta como FAAP
# CD_TOT_mg/L                             0.003                    0.003
# CALIDAD_CD                Potable - Excelente      Potable - Excelente
# CR_TOT_mg/L                             0.005                    0.005
# CALIDAD_CR                Potable - Excelente      Potable - Excelente
# HG_TOT_mg/L                            0.0005                   0.0005
# CALIDAD_HG                Potable - Excelente      Potable - Excelente
# PB_TOT_mg/L                             0.005                    0.005
# CALIDAD_PB                Potable - Excelente      Potable - Excelente
# MN_TOT_mg/L                            0.0015                   0.0015
# CALIDAD_MN                Potable - Excelente      Potable - Excelente
# FE_TOT_mg/L                            0.0891                    0.025
# CALIDAD_FE                Potable - Excelente      Potable - Excelente
# SEMAFORO                                Verde                    Verde
# CONTAMINANTES                             NaN                      NaN
# CUMPLE_CON_ALC                             SI                       SI
# CUMPLE_CON_COND                            SI                       SI
# CUMPLE_CON_SDT_ra                          SI                       SI
# CUMPLE_CON_SDT_salin                       SI                       SI
# CUMPLE_CON_FLUO                            SI                       SI
# CUMPLE_CON_DUR                             SI                       SI
# CUMPLE_CON_CF                              SI                       SI
# CUMPLE_CON_NO3                             SI                       SI
# CUMPLE_CON_AS                              SI                       SI
# CUMPLE_CON_CD                              SI                       SI
# CUMPLE_CON_CR                              SI                       SI
# CUMPLE_CON_HG                              SI                       SI
# CUMPLE_CON_PB                              SI                       SI
# CUMPLE_CON_MN                              SI                       SI
# CUMPLE_CON_FE                              SI                       SI
#
#                                             2                        3  \
# CLAVE                                  DLAGU7                   DLAGU9
# SITIO                              POZO COSIO       POZO EL SALITRILLO
# ORGANISMO_DE_CUENCA   LERMA SANTIAGO PACIFICO  LERMA SANTIAGO PACIFICO
# ESTADO                         AGUASCALIENTES           AGUASCALIENTES
# MUNICIPIO                               COSIO          RINCON DE ROMOS
# ACUIFERO              VALLE DE AGUASCALIENTES  VALLE DE AGUASCALIENTES
# SUBTIPO                                  POZO                     POZO
# LONGITUD                           -102.28801               -102.29449
# LATITUD                              22.36685                 22.18435
# PERIODO                                  2020                     2020
# ALC_mg/L                               204.92                    327.0
# CALIDAD_ALC                              Alta                     Alta
# CONDUCT_mS/cm                           532.0                    686.0
# CALIDAD_CONDUC               Buena para riego         Buena para riego
# SDT_mg/L                                  NaN                      NaN
# SDT_M_mg/L                              342.0                    478.6
# CALIDAD_SDT_ra           Excelente para riego     Excelente para riego
# CALIDAD_SDT_salin             Potable - Dulce          Potable - Dulce
# FLUORUROS_mg/L                         1.8045                   1.1229
# CALIDAD_FLUO                             Alta         Potable - Optima
# DUR_mg/L                              120.719                  199.879
# CALIDAD_DUR                    Potable - Dura           Potable - Dura
# COLI_FEC_NMP/100_mL                       1.1                      1.1
# CALIDAD_COLI_FEC          Potable - Excelente      Potable - Excelente
# N_NO3_mg/L                           1.449803                 1.258597
# CALIDAD_N_NO3             Potable - Excelente      Potable - Excelente
# AS_TOT_mg/L                             0.037                   0.0154
# CALIDAD_AS                  No apta como FAAP           Apta como FAAP
# CD_TOT_mg/L                             0.003                    0.003
# CALIDAD_CD                Potable - Excelente      Potable - Excelente
# CR_TOT_mg/L                             0.005                    0.005
# CALIDAD_CR                Potable - Excelente      Potable - Excelente
# HG_TOT_mg/L                            0.0005                   0.0005
# CALIDAD_HG                Potable - Excelente      Potable - Excelente
# PB_TOT_mg/L                             0.005                    0.005
# CALIDAD_PB                Potable - Excelente      Potable - Excelente
# MN_TOT_mg/L                            0.0015                   0.0015
# CALIDAD_MN                Potable - Excelente      Potable - Excelente
# FE_TOT_mg/L                             0.025                    0.025
# CALIDAD_FE                Potable - Excelente      Potable - Excelente
# SEMAFORO                                 Rojo                    Verde
# CONTAMINANTES                        FLUO,AS,                      NaN
# CUMPLE_CON_ALC                             SI                       SI
# CUMPLE_CON_COND                            SI                       SI
# CUMPLE_CON_SDT_ra                          SI                       SI
# CUMPLE_CON_SDT_salin                       SI                       SI
# CUMPLE_CON_FLUO                            NO                       SI
# CUMPLE_CON_DUR                             SI                       SI
# CUMPLE_CON_CF                              SI                       SI
# CUMPLE_CON_NO3                             SI                       SI
# CUMPLE_CON_AS                              NO                       SI
# CUMPLE_CON_CD                              SI                       SI
# CUMPLE_CON_CR                              SI                       SI
# CUMPLE_CON_HG                              SI                       SI
# CUMPLE_CON_PB                              SI                       SI
# CUMPLE_CON_MN                              SI                       SI
# CUMPLE_CON_FE                              SI                       SI
#
#                                                  4  \
# CLAVE                                     DLBAJ107
# SITIO                           RANCHO EL TECOLOTE
# ORGANISMO_DE_CUENCA   PENINSULA DE BAJA CALIFORNIA
# ESTADO                         BAJA CALIFORNIA SUR
# MUNICIPIO                                   LA PAZ
# ACUIFERO                              TODOS SANTOS
# SUBTIPO                                       POZO
# LONGITUD                                 -110.2448
# LATITUD                                   23.45138
# PERIODO                                       2020
# ALC_mg/L                                   309.885
# CALIDAD_ALC                                   Alta
# CONDUCT_mS/cm                               1841.0
# CALIDAD_CONDUC               Permisible para riego
# SDT_mg/L                                       NaN
# SDT_M_mg/L                                  1179.0
# CALIDAD_SDT_ra        Cultivos con manejo especial
# CALIDAD_SDT_salin             Ligeramente salobres
# FLUORUROS_mg/L                              0.2343
# CALIDAD_FLUO                                  Baja
# DUR_mg/L                                  476.9872
# CALIDAD_DUR                         Potable - Dura
# COLI_FEC_NMP/100_mL                          291.0
# CALIDAD_COLI_FEC                         Aceptable
# N_NO3_mg/L                               15.672251
# CALIDAD_N_NO3                    No apta como FAAP
# AS_TOT_mg/L                                   0.01
# CALIDAD_AS                     Potable - Excelente
# CD_TOT_mg/L                                  0.003
# CALIDAD_CD                     Potable - Excelente
# CR_TOT_mg/L                                  0.005
# CALIDAD_CR                     Potable - Excelente
# HG_TOT_mg/L                                 0.0005
# CALIDAD_HG                     Potable - Excelente
# PB_TOT_mg/L                                  0.005
# CALIDAD_PB                     Potable - Excelente
# MN_TOT_mg/L                                 0.0015
# CALIDAD_MN                     Potable - Excelente
# FE_TOT_mg/L                                  0.025
# CALIDAD_FE                     Potable - Excelente
# SEMAFORO                                      Rojo
# CONTAMINANTES                                 NO3,
# CUMPLE_CON_ALC                                  SI
# CUMPLE_CON_COND                                 SI
# CUMPLE_CON_SDT_ra                               SI
# CUMPLE_CON_SDT_salin                            SI
# CUMPLE_CON_FLUO                                 SI
# CUMPLE_CON_DUR                                  SI
# CUMPLE_CON_CF                                   SI
# CUMPLE_CON_NO3                                  NO
# CUMPLE_CON_AS                                   SI
# CUMPLE_CON_CD                                   SI
# CUMPLE_CON_CR                                   SI
# CUMPLE_CON_HG                                   SI
# CUMPLE_CON_PB                                   SI
# CUMPLE_CON_MN                                   SI
# CUMPLE_CON_FE                                   SI
#
#                                                             5  \
# CLAVE                                                DLBAJ108
# SITIO                 POZO A.P. CNA 7 (ANTES POZO A.P. CNA 6)
# ORGANISMO_DE_CUENCA              PENINSULA DE BAJA CALIFORNIA
# ESTADO                                    BAJA CALIFORNIA SUR
# MUNICIPIO                                              LA PAZ
# ACUIFERO                                         TODOS SANTOS
# SUBTIPO                                                  POZO
# LONGITUD                                           -110.22067
# LATITUD                                              23.46493
# PERIODO                                                  2020
# ALC_mg/L                                              224.475
# CALIDAD_ALC                                              Alta
# CONDUCT_mS/cm                                           570.3
# CALIDAD_CONDUC                               Buena para riego
# SDT_mg/L                                                  NaN
# SDT_M_mg/L                                              554.8
# CALIDAD_SDT_ra                             Cultivos sensibles
# CALIDAD_SDT_salin                             Potable - Dulce
# FLUORUROS_mg/L                                         0.2756
# CALIDAD_FLUO                                             Baja
# DUR_mg/L                                             201.8784
# CALIDAD_DUR                                    Potable - Dura
# COLI_FEC_NMP/100_mL                                    6131.0
# CALIDAD_COLI_FEC                                  Contaminada
# N_NO3_mg/L                                            8.55574
# CALIDAD_N_NO3                         Potable - Buena calidad
# AS_TOT_mg/L                                              0.01
# CALIDAD_AS                                Potable - Excelente
# CD_TOT_mg/L                                             0.003
# CALIDAD_CD                                Potable - Excelente
# CR_TOT_mg/L                                             0.005
# CALIDAD_CR                                Potable - Excelente
# HG_TOT_mg/L                                            0.0005
# CALIDAD_HG                                Potable - Excelente
# PB_TOT_mg/L                                             0.005
# CALIDAD_PB                                Potable - Excelente
# MN_TOT_mg/L                                            0.0015
# CALIDAD_MN                                Potable - Excelente
# FE_TOT_mg/L                                             0.025
# CALIDAD_FE                                Potable - Excelente
# SEMAFORO                                                 Rojo
# CONTAMINANTES                                             CF,
# CUMPLE_CON_ALC                                             SI
# CUMPLE_CON_COND                                            SI
# CUMPLE_CON_SDT_ra                                          SI
# CUMPLE_CON_SDT_salin                                       SI
# CUMPLE_CON_FLUO                                            SI
# CUMPLE_CON_DUR                                             SI
# CUMPLE_CON_CF                                              NO
# CUMPLE_CON_NO3                                             SI
# CUMPLE_CON_AS                                              SI
# CUMPLE_CON_CD                                              SI
# CUMPLE_CON_CR                                              SI
# CUMPLE_CON_HG                                              SI
# CUMPLE_CON_PB                                              SI
# CUMPLE_CON_MN                                              SI
# CUMPLE_CON_FE                                              SI
#
#                                                  6  \
# CLAVE                                     DLBAJ110
# SITIO                            POZO 26, SAN JUAN
# ORGANISMO_DE_CUENCA   PENINSULA DE BAJA CALIFORNIA
# ESTADO                         BAJA CALIFORNIA SUR
# MUNICIPIO                                   LA PAZ
# ACUIFERO                              TODOS SANTOS
# SUBTIPO                                       POZO
# LONGITUD                                -110.21396
# LATITUD                                    23.4746
# PERIODO                                       2020
# ALC_mg/L                                    203.67
# CALIDAD_ALC                                   Alta
# CONDUCT_mS/cm                                531.0
# CALIDAD_CONDUC                    Buena para riego
# SDT_mg/L                                       NaN
# SDT_M_mg/L                                   278.8
# CALIDAD_SDT_ra                Excelente para riego
# CALIDAD_SDT_salin                  Potable - Dulce
# FLUORUROS_mg/L                               0.289
# CALIDAD_FLUO                                  Baja
# DUR_mg/L                                  166.2528
# CALIDAD_DUR                         Potable - Dura
# COLI_FEC_NMP/100_mL                          110.0
# CALIDAD_COLI_FEC                     Buena calidad
# N_NO3_mg/L                                 4.68647
# CALIDAD_N_NO3                  Potable - Excelente
# AS_TOT_mg/L                                   0.01
# CALIDAD_AS                     Potable - Excelente
# CD_TOT_mg/L                                  0.003
# CALIDAD_CD                     Potable - Excelente
# CR_TOT_mg/L                                  0.005
# CALIDAD_CR                     Potable - Excelente
# HG_TOT_mg/L                                 0.0005
# CALIDAD_HG                     Potable - Excelente
# PB_TOT_mg/L                                  0.005
# CALIDAD_PB                     Potable - Excelente
# MN_TOT_mg/L                                 0.0015
# CALIDAD_MN                     Potable - Excelente
# FE_TOT_mg/L                                  0.025
# CALIDAD_FE                     Potable - Excelente
# SEMAFORO                                     Verde
# CONTAMINANTES                                  NaN
# CUMPLE_CON_ALC                                  SI
# CUMPLE_CON_COND                                 SI
# CUMPLE_CON_SDT_ra                               SI
# CUMPLE_CON_SDT_salin                            SI
# CUMPLE_CON_FLUO                                 SI
# CUMPLE_CON_DUR                                  SI
# CUMPLE_CON_CF                                   SI
# CUMPLE_CON_NO3                                  SI
# CUMPLE_CON_AS                                   SI
# CUMPLE_CON_CD                                   SI
# CUMPLE_CON_CR                                   SI
# CUMPLE_CON_HG                                   SI
# CUMPLE_CON_PB                                   SI
# CUMPLE_CON_MN                                   SI
# CUMPLE_CON_FE                                   SI
#
#                                                  7  \
# CLAVE                                     DLBAJ111
# SITIO                           VICTOR HUGO CESEÑA
# ORGANISMO_DE_CUENCA   PENINSULA DE BAJA CALIFORNIA
# ESTADO                         BAJA CALIFORNIA SUR
# MUNICIPIO                                LOS CABOS
# ACUIFERO                            CABO SAN LUCAS
# SUBTIPO                                       POZO
# LONGITUD                               -109.907306
# LATITUD                                    22.8905
# PERIODO                                       2020
# ALC_mg/L                                    350.76
# CALIDAD_ALC                                   Alta
# CONDUCT_mS/cm                               2253.3
# CALIDAD_CONDUC                   Dudosa para riego
# SDT_mg/L                                       NaN
# SDT_M_mg/L                                  1160.2
# CALIDAD_SDT_ra        Cultivos con manejo especial
# CALIDAD_SDT_salin             Ligeramente salobres
# FLUORUROS_mg/L                              0.5607
# CALIDAD_FLUO                                 Media
# DUR_mg/L                                  269.1712
# CALIDAD_DUR                         Potable - Dura
# COLI_FEC_NMP/100_mL                          798.0
# CALIDAD_COLI_FEC                         Aceptable
# N_NO3_mg/L                               27.600998
# CALIDAD_N_NO3                    No apta como FAAP
# AS_TOT_mg/L                                   0.01
# CALIDAD_AS                     Potable - Excelente
# CD_TOT_mg/L                                  0.003
# CALIDAD_CD                     Potable - Excelente
# CR_TOT_mg/L                                  0.005
# CALIDAD_CR                     Potable - Excelente
# HG_TOT_mg/L                                 0.0005
# CALIDAD_HG                     Potable - Excelente
# PB_TOT_mg/L                                  0.005
# CALIDAD_PB                     Potable - Excelente
# MN_TOT_mg/L                                 0.0041
# CALIDAD_MN                     Potable - Excelente
# FE_TOT_mg/L                                 0.0692
# CALIDAD_FE                     Potable - Excelente
# SEMAFORO                                      Rojo
# CONTAMINANTES                          CONDUC,NO3,
# CUMPLE_CON_ALC                                  SI
# CUMPLE_CON_COND                                 NO
# CUMPLE_CON_SDT_ra                               SI
# CUMPLE_CON_SDT_salin                            SI
# CUMPLE_CON_FLUO                                 SI
# CUMPLE_CON_DUR                                  SI
# CUMPLE_CON_CF                                   SI
# CUMPLE_CON_NO3                                  NO
# CUMPLE_CON_AS                                   SI
# CUMPLE_CON_CD                                   SI
# CUMPLE_CON_CR                                   SI
# CUMPLE_CON_HG                                   SI
# CUMPLE_CON_PB                                   SI
# CUMPLE_CON_MN                                   SI
# CUMPLE_CON_FE                                   SI
#
#                                                  8  \
# CLAVE                                     DLBAJ117
# SITIO                                 LAS PARRITAS
# ORGANISMO_DE_CUENCA   PENINSULA DE BAJA CALIFORNIA
# ESTADO                         BAJA CALIFORNIA SUR
# MUNICIPIO                                   LA PAZ
# ACUIFERO                               EL CARRIZAL
# SUBTIPO                                       POZO
# LONGITUD                               -110.088778
# LATITUD                                  23.799861
# PERIODO                                       2020
# ALC_mg/L                                   343.655
# CALIDAD_ALC                                   Alta
# CONDUCT_mS/cm                               1114.0
# CALIDAD_CONDUC               Permisible para riego
# SDT_mg/L                                       NaN
# SDT_M_mg/L                                   672.0
# CALIDAD_SDT_ra                  Cultivos sensibles
# CALIDAD_SDT_salin                  Potable - Dulce
# FLUORUROS_mg/L                              0.3421
# CALIDAD_FLUO                                  Baja
# DUR_mg/L                                  403.8482
# CALIDAD_DUR                         Potable - Dura
# COLI_FEC_NMP/100_mL                          146.0
# CALIDAD_COLI_FEC                     Buena calidad
# N_NO3_mg/L                                1.877325
# CALIDAD_N_NO3                  Potable - Excelente
# AS_TOT_mg/L                                   0.01
# CALIDAD_AS                     Potable - Excelente
# CD_TOT_mg/L                                  0.003
# CALIDAD_CD                     Potable - Excelente
# CR_TOT_mg/L                                  0.005
# CALIDAD_CR                     Potable - Excelente
# HG_TOT_mg/L                                 0.0005
# CALIDAD_HG                     Potable - Excelente
# PB_TOT_mg/L                                  0.005
# CALIDAD_PB                     Potable - Excelente
# MN_TOT_mg/L                                 0.0113
# CALIDAD_MN                     Potable - Excelente
# FE_TOT_mg/L                                 0.1615
# CALIDAD_FE                     Potable - Excelente
# SEMAFORO                                     Verde
# CONTAMINANTES                                  NaN
# CUMPLE_CON_ALC                                  SI
# CUMPLE_CON_COND                                 SI
# CUMPLE_CON_SDT_ra                               SI
# CUMPLE_CON_SDT_salin                            SI
# CUMPLE_CON_FLUO                                 SI
# CUMPLE_CON_DUR                                  SI
# CUMPLE_CON_CF                                   SI
# CUMPLE_CON_NO3                                  SI
# CUMPLE_CON_AS                                   SI
# CUMPLE_CON_CD                                   SI
# CUMPLE_CON_CR                                   SI
# CUMPLE_CON_HG                                   SI
# CUMPLE_CON_PB                                   SI
# CUMPLE_CON_MN                                   SI
# CUMPLE_CON_FE                                   SI
#
#                                                                       9
# CLAVE                                                          DLBAJ118
# SITIO                                                       SAN ANTONIO
# ORGANISMO_DE_CUENCA                        PENINSULA DE BAJA CALIFORNIA
# ESTADO                                              BAJA CALIFORNIA SUR
# MUNICIPIO                                                        LA PAZ
# ACUIFERO                                                     LOS PLANES
# SUBTIPO                                                            POZO
# LONGITUD                                                    -110.054722
# LATITUD                                                       23.824722
# PERIODO                                                            2020
# ALC_mg/L                                                        332.605
# CALIDAD_ALC                                                        Alta
# CONDUCT_mS/cm                                                    1703.0
# CALIDAD_CONDUC                                    Permisible para riego
# SDT_mg/L                                                            NaN
# SDT_M_mg/L                                                       1017.8
# CALIDAD_SDT_ra                             Cultivos con manejo especial
# CALIDAD_SDT_salin                                  Ligeramente salobres
# FLUORUROS_mg/L                                                   0.5088
# CALIDAD_FLUO                                                      Media
# DUR_mg/L                                                       559.0214
# CALIDAD_DUR           Muy dura e indeseable usos industrial y domestico
# COLI_FEC_NMP/100_mL                                              3873.0
# CALIDAD_COLI_FEC                                            Contaminada
# N_NO3_mg/L                                                     0.143061
# CALIDAD_N_NO3                                       Potable - Excelente
# AS_TOT_mg/L                                                      0.3558
# CALIDAD_AS                                            No apta como FAAP
# CD_TOT_mg/L                                                       0.003
# CALIDAD_CD                                          Potable - Excelente
# CR_TOT_mg/L                                                       0.005
# CALIDAD_CR                                          Potable - Excelente
# HG_TOT_mg/L                                                      0.0005
# CALIDAD_HG                                          Potable - Excelente
# PB_TOT_mg/L                                                       0.005
# CALIDAD_PB                                          Potable - Excelente
# MN_TOT_mg/L                                                       1.167
# CALIDAD_MN                                       Puede afectar la salud
# FE_TOT_mg/L                                                       14.06
# CALIDAD_FE            Sin efectos en la salud - Puede dar color al agua
# SEMAFORO                                                           Rojo
# CONTAMINANTES                                           DT,CF,AS,MN,FE,
# CUMPLE_CON_ALC                                                       SI
# CUMPLE_CON_COND                                                      SI
# CUMPLE_CON_SDT_ra                                                    SI
# CUMPLE_CON_SDT_salin                                                 SI
# CUMPLE_CON_FLUO                                                      SI
# CUMPLE_CON_DUR                                                       NO
# CUMPLE_CON_CF                                                        NO
# CUMPLE_CON_NO3                                                       SI
# CUMPLE_CON_AS                                                        NO
# CUMPLE_CON_CD                                                        SI
# CUMPLE_CON_CR                                                        SI
# CUMPLE_CON_HG                                                        SI
# CUMPLE_CON_PB                                                        SI
# CUMPLE_CON_MN                                                        NO
# CUMPLE_CON_FE                                                        NO

# %%
df_sub.describe(include='all').T
# Out:
#                        count unique                          top  freq  \
# CLAVE                   1068   1068                       DLAGU6     1
# SITIO                   1068   1066                    EL FUERTE     2
# ORGANISMO_DE_CUENCA     1068     13  CUENCAS CENTRALES DEL NORTE   232
# ESTADO                  1068     32                      DURANGO   121
# MUNICIPIO               1068    452                       LA PAZ    27
# ACUIFERO                1068    273         PENINSULA DE YUCATAN   119
# SUBTIPO                 1068      8                         POZO  1039
# LONGITUD              1068.0    NaN                          NaN   NaN
# LATITUD               1068.0    NaN                          NaN   NaN
# PERIODO               1068.0    NaN                          NaN   NaN
# ALC_mg/L              1064.0    NaN                          NaN   NaN
# CALIDAD_ALC             1064      4                         Alta   794
# CONDUCT_mS/cm         1062.0    NaN                          NaN   NaN
# CALIDAD_CONDUC          1062      5        Permisible para riego   460
# SDT_mg/L                 0.0    NaN                          NaN   NaN
# SDT_M_mg/L            1066.0    NaN                          NaN   NaN
# CALIDAD_SDT_ra          1066      5         Excelente para riego   491
# CALIDAD_SDT_salin       1066      4              Potable - Dulce   834
# FLUORUROS_mg/L        1068.0    NaN                          NaN   NaN
# CALIDAD_FLUO            1068      4                         Baja   434
# DUR_mg/L              1067.0    NaN                          NaN   NaN
# CALIDAD_DUR             1067      4               Potable - Dura   577
# COLI_FEC_NMP/100_mL   1068.0    NaN                          NaN   NaN
# CALIDAD_COLI_FEC        1068      5          Potable - Excelente   739
# N_NO3_mg/L            1067.0    NaN                          NaN   NaN
# CALIDAD_N_NO3           1067      3          Potable - Excelente   788
# AS_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_AS              1068      3          Potable - Excelente   816
# CD_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_CD              1068      2          Potable - Excelente  1066
# CR_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_CR              1068      2          Potable - Excelente  1053
# HG_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_HG              1068      2          Potable - Excelente  1067
# PB_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_PB              1068      2          Potable - Excelente  1056
# MN_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_MN              1068      3          Potable - Excelente   982
# FE_TOT_mg/L           1068.0    NaN                          NaN   NaN
# CALIDAD_FE              1068      2          Potable - Excelente   932
# SEMAFORO                1068      3                        Verde   434
# CONTAMINANTES            634    126                        FLUO,    78
# CUMPLE_CON_ALC          1068      3                           SI  1005
# CUMPLE_CON_COND         1068      3                           SI   939
# CUMPLE_CON_SDT_ra       1068      3                           SI   995
# CUMPLE_CON_SDT_salin    1068      3                           SI   995
# CUMPLE_CON_FLUO         1068      2                           SI   876
# CUMPLE_CON_DUR          1068      3                           SI   841
# CUMPLE_CON_CF           1068      2                           SI  1007
# CUMPLE_CON_NO3          1068      3                           SI   985
# CUMPLE_CON_AS           1068      2                           SI   941
# CUMPLE_CON_CD           1068      2                           SI  1066
# CUMPLE_CON_CR           1068      2                           SI  1053
# CUMPLE_CON_HG           1068      2                           SI  1067
# CUMPLE_CON_PB           1068      2                           SI  1056
# CUMPLE_CON_MN           1068      2                           SI   982
# CUMPLE_CON_FE           1068      2                           SI   932
#
#                              mean          std        min         25%  \
# CLAVE                         NaN          NaN        NaN         NaN
# SITIO                         NaN          NaN        NaN         NaN
# ORGANISMO_DE_CUENCA           NaN          NaN        NaN         NaN
# ESTADO                        NaN          NaN        NaN         NaN
# MUNICIPIO                     NaN          NaN        NaN         NaN
# ACUIFERO                      NaN          NaN        NaN         NaN
# SUBTIPO                       NaN          NaN        NaN         NaN
# LONGITUD              -101.891007     6.703263 -116.66425 -105.388865
# LATITUD                 23.163618      3.88767   14.56115   20.212055
# PERIODO                    2020.0          0.0     2020.0      2020.0
# ALC_mg/L               235.633759   116.874291      26.64       164.0
# CALIDAD_ALC                   NaN          NaN        NaN         NaN
# CONDUCT_mS/cm         1138.953013  1245.563674       50.4      501.75
# CALIDAD_CONDUC                NaN          NaN        NaN         NaN
# SDT_mg/L                      NaN          NaN        NaN         NaN
# SDT_M_mg/L             896.101567   2751.53059       25.0       337.5
# CALIDAD_SDT_ra                NaN          NaN        NaN         NaN
# CALIDAD_SDT_salin             NaN          NaN        NaN         NaN
# FLUORUROS_mg/L             1.0756     1.924278        0.2    0.267175
# CALIDAD_FLUO                  NaN          NaN        NaN         NaN
# DUR_mg/L               347.938073   359.669452       20.0    121.1948
# CALIDAD_DUR                   NaN          NaN        NaN         NaN
# COLI_FEC_NMP/100_mL    355.490356  2052.457014        1.1         1.1
# CALIDAD_COLI_FEC              NaN          NaN        NaN         NaN
# N_NO3_mg/L               4.319759     8.345134       0.02    0.650294
# CALIDAD_N_NO3                 NaN          NaN        NaN         NaN
# AS_TOT_mg/L              0.019618     0.035209       0.01        0.01
# CALIDAD_AS                    NaN          NaN        NaN         NaN
# CD_TOT_mg/L               0.00303     0.000894      0.003       0.003
# CALIDAD_CD                    NaN          NaN        NaN         NaN
# CR_TOT_mg/L              0.013276     0.154391      0.005       0.005
# CALIDAD_CR                    NaN          NaN        NaN         NaN
# HG_TOT_mg/L              0.000557     0.000467     0.0005      0.0005
# CALIDAD_HG                    NaN          NaN        NaN         NaN
# PB_TOT_mg/L              0.005282     0.003254      0.005       0.005
# CALIDAD_PB                    NaN          NaN        NaN         NaN
# MN_TOT_mg/L              0.072478     0.376512     0.0015      0.0015
# CALIDAD_MN                    NaN          NaN        NaN         NaN
# FE_TOT_mg/L              0.410387     5.537974      0.025       0.025
# CALIDAD_FE                    NaN          NaN        NaN         NaN
# SEMAFORO                      NaN          NaN        NaN         NaN
# CONTAMINANTES                 NaN          NaN        NaN         NaN
# CUMPLE_CON_ALC                NaN          NaN        NaN         NaN
# CUMPLE_CON_COND               NaN          NaN        NaN         NaN
# CUMPLE_CON_SDT_ra             NaN          NaN        NaN         NaN
# CUMPLE_CON_SDT_salin          NaN          NaN        NaN         NaN
# CUMPLE_CON_FLUO               NaN          NaN        NaN         NaN
# CUMPLE_CON_DUR                NaN          NaN        NaN         NaN
# CUMPLE_CON_CF                 NaN          NaN        NaN         NaN
# CUMPLE_CON_NO3                NaN          NaN        NaN         NaN
# CUMPLE_CON_AS                 NaN          NaN        NaN         NaN
# CUMPLE_CON_CD                 NaN          NaN        NaN         NaN
# CUMPLE_CON_CR                 NaN          NaN        NaN         NaN
# CUMPLE_CON_HG                 NaN          NaN        NaN         NaN
# CUMPLE_CON_PB                 NaN          NaN        NaN         NaN
# CUMPLE_CON_MN                 NaN          NaN        NaN         NaN
# CUMPLE_CON_FE                 NaN          NaN        NaN         NaN
#
#                             50%        75%         max
# CLAVE                       NaN        NaN         NaN
# SITIO                       NaN        NaN         NaN
# ORGANISMO_DE_CUENCA         NaN        NaN         NaN
# ESTADO                      NaN        NaN         NaN
# MUNICIPIO                   NaN        NaN         NaN
# ACUIFERO                    NaN        NaN         NaN
# SUBTIPO                     NaN        NaN         NaN
# LONGITUD             -102.17418 -98.974716   -86.86412
# LATITUD                22.61719  25.510285   32.677713
# PERIODO                  2020.0     2020.0      2020.0
# ALC_mg/L               215.5275     292.71      1650.0
# CALIDAD_ALC                 NaN        NaN         NaN
# CONDUCT_mS/cm             815.0    1322.75     18577.0
# CALIDAD_CONDUC              NaN        NaN         NaN
# SDT_mg/L                    NaN        NaN         NaN
# SDT_M_mg/L                550.4      916.1     82170.0
# CALIDAD_SDT_ra              NaN        NaN         NaN
# CALIDAD_SDT_salin           NaN        NaN         NaN
# FLUORUROS_mg/L           0.5035    1.13985     34.8033
# CALIDAD_FLUO                NaN        NaN         NaN
# DUR_mg/L               245.3358     453.93   3810.6922
# CALIDAD_DUR                 NaN        NaN         NaN
# COLI_FEC_NMP/100_mL         1.1      13.25     24196.0
# CALIDAD_COLI_FEC            NaN        NaN         NaN
# N_NO3_mg/L             2.080932   5.201698  121.007813
# CALIDAD_N_NO3               NaN        NaN         NaN
# AS_TOT_mg/L                0.01       0.01      0.4522
# CALIDAD_AS                  NaN        NaN         NaN
# CD_TOT_mg/L               0.003      0.003     0.03211
# CALIDAD_CD                  NaN        NaN         NaN
# CR_TOT_mg/L               0.005      0.005      5.0032
# CALIDAD_CR                  NaN        NaN         NaN
# HG_TOT_mg/L              0.0005     0.0005     0.01415
# CALIDAD_HG                  NaN        NaN         NaN
# PB_TOT_mg/L               0.005      0.005      0.0809
# CALIDAD_PB                  NaN        NaN         NaN
# MN_TOT_mg/L              0.0015   0.009947       8.982
# CALIDAD_MN                  NaN        NaN         NaN
# FE_TOT_mg/L             0.04696    0.17338     178.615
# CALIDAD_FE                  NaN        NaN         NaN
# SEMAFORO                    NaN        NaN         NaN
# CONTAMINANTES               NaN        NaN         NaN
# CUMPLE_CON_ALC              NaN        NaN         NaN
# CUMPLE_CON_COND             NaN        NaN         NaN
# CUMPLE_CON_SDT_ra           NaN        NaN         NaN
# CUMPLE_CON_SDT_salin        NaN        NaN         NaN
# CUMPLE_CON_FLUO             NaN        NaN         NaN
# CUMPLE_CON_DUR              NaN        NaN         NaN
# CUMPLE_CON_CF               NaN        NaN         NaN
# CUMPLE_CON_NO3              NaN        NaN         NaN
# CUMPLE_CON_AS               NaN        NaN         NaN
# CUMPLE_CON_CD               NaN        NaN         NaN
# CUMPLE_CON_CR               NaN        NaN         NaN
# CUMPLE_CON_HG               NaN        NaN         NaN
# CUMPLE_CON_PB               NaN        NaN         NaN
# CUMPLE_CON_MN               NaN        NaN         NaN
# CUMPLE_CON_FE               NaN        NaN         NaN

# %%
#vamos a ver el tipo de datos que tenemos por columna
df_sub.dtypes
# Out:
# CLAVE                    object
# SITIO                    object
# ORGANISMO_DE_CUENCA      object
# ESTADO                   object
# MUNICIPIO                object
# ACUIFERO                 object
# SUBTIPO                  object
# LONGITUD                float64
# LATITUD                 float64
# PERIODO                   int64
# ALC_mg/L                float64
# CALIDAD_ALC              object
# CONDUCT_mS/cm           float64
# CALIDAD_CONDUC           object
# SDT_mg/L                float64
# SDT_M_mg/L              float64
# CALIDAD_SDT_ra           object
# CALIDAD_SDT_salin        object
# FLUORUROS_mg/L          float64
# CALIDAD_FLUO             object
# DUR_mg/L                float64
# CALIDAD_DUR              object
# COLI_FEC_NMP/100_mL     float64
# CALIDAD_COLI_FEC         object
# N_NO3_mg/L              float64
# CALIDAD_N_NO3            object
# AS_TOT_mg/L             float64
# CALIDAD_AS               object
# CD_TOT_mg/L             float64
# CALIDAD_CD               object
# CR_TOT_mg/L             float64
# CALIDAD_CR               object
# HG_TOT_mg/L             float64
# CALIDAD_HG               object
# PB_TOT_mg/L             float64
# CALIDAD_PB               object
# MN_TOT_mg/L             float64
# CALIDAD_MN               object
# FE_TOT_mg/L             float64
# CALIDAD_FE               object
# SEMAFORO                 object
# CONTAMINANTES            object
# CUMPLE_CON_ALC           object
# CUMPLE_CON_COND          object
# CUMPLE_CON_SDT_ra        object
# CUMPLE_CON_SDT_salin     object
# CUMPLE_CON_FLUO          object
# CUMPLE_CON_DUR           object
# CUMPLE_CON_CF            object
# CUMPLE_CON_NO3           object
# CUMPLE_CON_AS            object
# CUMPLE_CON_CD            object
# CUMPLE_CON_CR            object
# CUMPLE_CON_HG            object
# CUMPLE_CON_PB            object
# CUMPLE_CON_MN            object
# CUMPLE_CON_FE            object
# dtype: object

# %% [markdown]
# ## Seleccion de columnas categóricas

# %%
#para separar todas las categóricas
categorical_columns = [col for col in df_sub.columns if df_sub[col].dtypes == object]

#para separar las categóricas sin incluir CLAVE
#categorical_columns = [col for col in df_sub.columns if df_sub[col].dtypes == object][1:0]

print(len(categorical_columns), categorical_columns)
# Out:
# 39 ['CLAVE', 'SITIO', 'ORGANISMO_DE_CUENCA', 'ESTADO', 'MUNICIPIO', 'ACUIFERO', 'SUBTIPO', 'CALIDAD_ALC', 'CALIDAD_CONDUC', 'CALIDAD_SDT_ra', 'CALIDAD_SDT_salin', 'CALIDAD_FLUO', 'CALIDAD_DUR', 'CALIDAD_COLI_FEC', 'CALIDAD_N_NO3', 'CALIDAD_AS', 'CALIDAD_CD', 'CALIDAD_CR', 'CALIDAD_HG', 'CALIDAD_PB', 'CALIDAD_MN', 'CALIDAD_FE', 'SEMAFORO', 'CONTAMINANTES', 'CUMPLE_CON_ALC', 'CUMPLE_CON_COND', 'CUMPLE_CON_SDT_ra', 'CUMPLE_CON_SDT_salin', 'CUMPLE_CON_FLUO', 'CUMPLE_CON_DUR', 'CUMPLE_CON_CF', 'CUMPLE_CON_NO3', 'CUMPLE_CON_AS', 'CUMPLE_CON_CD', 'CUMPLE_CON_CR', 'CUMPLE_CON_HG', 'CUMPLE_CON_PB', 'CUMPLE_CON_MN', 'CUMPLE_CON_FE']

# %% [markdown]
# ## Seleccion de columnas numéricas

# %%
float_columns = [col for col in df_sub.columns if df_sub[col].dtypes != object]
print(len(float_columns), float_columns)
# Out:
# 18 ['LONGITUD', 'LATITUD', 'PERIODO', 'ALC_mg/L', 'CONDUCT_mS/cm', 'SDT_mg/L', 'SDT_M_mg/L', 'FLUORUROS_mg/L', 'DUR_mg/L', 'COLI_FEC_NMP/100_mL', 'N_NO3_mg/L', 'AS_TOT_mg/L', 'CD_TOT_mg/L', 'CR_TOT_mg/L', 'HG_TOT_mg/L', 'PB_TOT_mg/L', 'MN_TOT_mg/L', 'FE_TOT_mg/L']

# %% [markdown]
# ## Balance de categorias

# %%
#Lista de semaforo
df_sub['SEMAFORO'].unique().tolist()
# Out:
# ['Verde', 'Rojo', 'Amarillo']

# %% [markdown]
# Conteo de datos deacuerdo a su etiqueta de semaforo

# %%
color_list = ['green','red', 'yellow']

fig, ax = plt.subplots(figsize=(10,4))

ax = sns.countplot(data=df_sub, x='SEMAFORO',  palette=color_list)

for p in ax.patches:
  ax.annotate(p.get_height(), (p.get_x()+0.25,p.get_height()+5))

plt.show()

# %%
semaforo = Counter(df_sub['SEMAFORO'])
colors_palete = sns.color_palette(color_list)

fig, ax = plt.subplots(figsize=(10,4))

plt.pie(semaforo.values(), labels=semaforo.keys(), colors=colors_palete, autopct='%.0f%%')

plt.show()

# %% [markdown]
# ## Visualizacion de datos perdidos

# %%
msno.matrix(df_sub, labels=list(df_sub.columns))
plt.show()

# %%
#esta variable no tiene nada.
df_sub['SDT_mg/L'].unique()
df_sub['SDT_mg/L'].value_counts()
# Out:
# Series([], Name: SDT_mg/L, dtype: int64)

# %%
#esta variable solo tiene un dato.
df_sub['PERIODO'].unique()
df_sub['PERIODO'].value_counts()
# Out:
# 2020    1068
# Name: PERIODO, dtype: int64

# %% [markdown]
# ## Distribucion de datos contiuos

# %% [markdown]
# ### Histogramas

# %%
sns.set(rc={'figure.figsize':(25,16)})
i = 0
fig, axes = plt.subplots(3, 6)    
for col in float_columns:
  plt.subplot(3,6,i+1)    
  plt.hist(df_sub[col].dropna(), bins=40)   
  plt.xlabel(col)
  i+=1

fig.suptitle('Histogramas de variables continuas')
plt.show()

# %% [markdown]
# ### Boxplots

# %%
sns.set(rc={'figure.figsize':(25,16)})
i = 0
fig, axes = plt.subplots(3, 6)    
for col in float_columns:
  plt.subplot(3,6,i+1)    
  plt.boxplot(df_sub[col].dropna(), showmeans=True, vert=False)   
  plt.xlabel(col)
  i+=1

fig.suptitle('Histogramas de variables continuas')
plt.show()

# %% [markdown]
# ### Boxplots por semaforo

# %%
sns.set(rc={'figure.figsize':(25,23)})
fig, axes = plt.subplots(6, 3)    
i = 0

for col in float_columns:
    plt.subplot(6,3,i+1) 
    sns.boxplot(y='SEMAFORO',
                x=col,
                data=df_sub,
                orient='horizontal',
                palette=colors_palete)
    plt.xlabel(col)
    i+=1

# %% [markdown]
# ### Correlacion de columnas continuas

# %%
sns.set(rc={'figure.figsize':(15,14)}) 

sns.heatmap(df_sub.corr(method='pearson'), cmap='PiYG', annot=True, fmt='.2f', vmin=-1, vmax=1)

plt.show()

# %% [markdown]
# ## Contaminantes

# %% [markdown]
# Conteo de contaminates para cada dato

# %%
#esto lo hacemos para convertir la lista de contaminantes a un número entero mediante conteo.
#NaN significa que no tiene contaminantes.
for row in df_sub.index:
  try:
    df_sub.at[row,"CONTAMINANTES"] = len(df_sub.loc[row]["CONTAMINANTES"])
  except:
    pass

# %%
df_sub["CONTAMINANTES"]
# Out:
# 0       NaN
# 1       NaN
# 2         8
# 3       NaN
# 4         4
#        ...
# 1063     14
# 1064      4
# 1065     14
# 1066    NaN
# 1067    NaN
# Name: CONTAMINANTES, Length: 1068, dtype: object

# %%
porcentaje_na=(df_sub["CONTAMINANTES"].isna().sum()/df_sub["CONTAMINANTES"].shape[0])*100
print(round(porcentaje_na, 2),"%")
# Out:
# 40.64 %

# %%
df_sub['CONTAMINANTES'].fillna(value = 0, inplace=True)
df_sub["CONTAMINANTES"] = df_sub["CONTAMINANTES"].astype(int)

# %%
df_sub["CONTAMINANTES"].min(),df_sub["CONTAMINANTES"].max(),df_sub["CONTAMINANTES"].value_counts()
# Out:
# (0,
#  45,
#  0     434
#  3     185
#  5      78
#  8      70
#  6      52
#  4      38
#  7      34
#  10     34
#  9      20
#  27     18
#  11     13
#  13     12
#  14      8
#  12      7
#  31      7
#  30      6
#  23      5
#  33      5
#  36      4
#  34      4
#  15      4
#  39      3
#  20      3
#  16      3
#  35      3
#  24      3
#  38      2
#  29      2
#  37      2
#  42      2
#  18      2
#  26      1
#  17      1
#  45      1
#  32      1
#  21      1
#  Name: CONTAMINANTES, dtype: int64)

# %% [markdown]
# ## Contaminantes por semaforo

# %%
#Evaluamos la cantidad de contaminantes, se evidencia que la clase verde en el semáforo no tiene contaminantes.

# %%
df_contamientes = df_sub.groupby(['SEMAFORO'], as_index=False).agg({'CONTAMINANTES':'sum'})
df_contamientes
# Out:
#    SEMAFORO  CONTAMINANTES
# 0  Amarillo           1969
# 1      Rojo           3627
# 2     Verde              0

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax = sns.barplot(data=df_contamientes, x='SEMAFORO', y='CONTAMINANTES', palette=['yellow','red', 'green'])

for p in ax.patches:
  ax.annotate(p.get_height(), (p.get_x()+0.25,p.get_height()+5))

plt.show()

# %% [markdown]
# ## Dataframe acondicionado

# %%
#en una nueva variable reemplazamos las palabras por números para realizar un mejor tratamiento de la información
df_sub['SEMAFORO_cat'] = df_sub['SEMAFORO'].replace({'Verde':0,
                                                     'Amarillo':1,
                                                     'Rojo':2})

df_sub['SEMAFORO_cat'] = df_sub['SEMAFORO_cat'].astype(int)

# %%
#eliminamos las variables que no aportan al análisis
df_sub_clean = df_sub.drop(['SEMAFORO', 'PERIODO', 'SDT_mg/L'], axis=1)

# %%
df_sub_clean.dtypes
# Out:
# CLAVE                    object
# SITIO                    object
# ORGANISMO_DE_CUENCA      object
# ESTADO                   object
# MUNICIPIO                object
# ACUIFERO                 object
# SUBTIPO                  object
# LONGITUD                float64
# LATITUD                 float64
# ALC_mg/L                float64
# CALIDAD_ALC              object
# CONDUCT_mS/cm           float64
# CALIDAD_CONDUC           object
# SDT_M_mg/L              float64
# CALIDAD_SDT_ra           object
# CALIDAD_SDT_salin        object
# FLUORUROS_mg/L          float64
# CALIDAD_FLUO             object
# DUR_mg/L                float64
# CALIDAD_DUR              object
# COLI_FEC_NMP/100_mL     float64
# CALIDAD_COLI_FEC         object
# N_NO3_mg/L              float64
# CALIDAD_N_NO3            object
# AS_TOT_mg/L             float64
# CALIDAD_AS               object
# CD_TOT_mg/L             float64
# CALIDAD_CD               object
# CR_TOT_mg/L             float64
# CALIDAD_CR               object
# HG_TOT_mg/L             float64
# CALIDAD_HG               object
# PB_TOT_mg/L             float64
# CALIDAD_PB               object
# MN_TOT_mg/L             float64
# CALIDAD_MN               object
# FE_TOT_mg/L             float64
# CALIDAD_FE               object
# CONTAMINANTES             int32
# CUMPLE_CON_ALC           object
# CUMPLE_CON_COND          object
# CUMPLE_CON_SDT_ra        object
# CUMPLE_CON_SDT_salin     object
# CUMPLE_CON_FLUO          object
# CUMPLE_CON_DUR           object
# CUMPLE_CON_CF            object
# CUMPLE_CON_NO3           object
# CUMPLE_CON_AS            object
# CUMPLE_CON_CD            object
# CUMPLE_CON_CR            object
# CUMPLE_CON_HG            object
# CUMPLE_CON_PB            object
# CUMPLE_CON_MN            object
# CUMPLE_CON_FE            object
# SEMAFORO_cat              int32
# dtype: object

# %%
clean_float_columns = [col for col in df_sub_clean.columns if df_sub_clean[col].dtypes != object]
print(len(clean_float_columns), clean_float_columns)
# Out:
# 18 ['LONGITUD', 'LATITUD', 'ALC_mg/L', 'CONDUCT_mS/cm', 'SDT_M_mg/L', 'FLUORUROS_mg/L', 'DUR_mg/L', 'COLI_FEC_NMP/100_mL', 'N_NO3_mg/L', 'AS_TOT_mg/L', 'CD_TOT_mg/L', 'CR_TOT_mg/L', 'HG_TOT_mg/L', 'PB_TOT_mg/L', 'MN_TOT_mg/L', 'FE_TOT_mg/L', 'CONTAMINANTES', 'SEMAFORO_cat']

# %% [markdown]
# ### Visualizacion de dataframe acondicionado

# %%
clean_color_list = ['green','yellow','red']
clean_colors_palete = sns.color_palette(clean_color_list)

# %%
  sns.set(rc={'figure.figsize':(25,23)})
  fig, axes = plt.subplots(6, 3)    
  i = 0

  for col in clean_float_columns[:-1]:
    plt.subplot(6,3,i+1) 
    sns.boxplot(y='SEMAFORO_cat',
                x=col,
                data=df_sub,
                orient='horizontal',
                palette=clean_colors_palete)
    plt.xlabel(col)
    i+=1
  print("------------------------ ")
# Out:
# ------------------------

# %%
sns.set(rc={'figure.figsize':(15,14)}) 

sns.heatmap(df_sub_clean.corr(method='pearson'), cmap='PiYG', annot=True, fmt='.2f', vmin=-1, vmax=1)

plt.show()

# %% [markdown]
# Existe alta correlacio con la cantidad de contamiantes y el codigo de semaforo

# %%
#sns.set(rc={'figure.figsize':(18,12)})
#sns.pairplot(df_sub_clean, height=5, diag_kind='auto', corner=False, hue='SEMAFORO_cat', palette=clean_colors_palete)
#plt.show()

# %% [markdown]
# Vamos a graficar las coordenadas

# %%
df_sub_clean["Coordinates"] = list(zip(df_sub_clean.LONGITUD, df_sub_clean.LATITUD))
df_sub_clean["Coordinates"] = df_sub_clean["Coordinates"].apply(Point)

# %%
df_sub_clean['SEMAFORO_cat'].unique()
# Out:
# array([0, 2, 1])

# %%
latlong=df_sub_clean[['LATITUD','LONGITUD', 'SEMAFORO_cat']]

sns.set(rc={'figure.figsize':(18,12)})
latlong.plot.scatter('LONGITUD','LATITUD', c='SEMAFORO_cat', cmap=ListedColormap(clean_color_list))

plt.show()

# %%
df_sub_clean['ORGANISMO_DE_CUENCA'].value_counts().count()
df_sub_clean['ORGANISMO_DE_CUENCA'].unique()
# Out:
# array(['LERMA SANTIAGO PACIFICO', 'PENINSULA DE BAJA CALIFORNIA',
#        'PENINSULA DE YUCATAN', 'RIO BRAVO', 'CUENCAS CENTRALES DEL NORTE',
#        'PACIFICO NORTE', 'BALSAS', 'PACIFICO SUR', 'GOLFO NORTE',
#        'AGUAS DEL VALLE DE MEXICO', 'GOLFO CENTRO', 'FRONTERA SUR',
#        'NOROESTE'], dtype=object)

# %%
#en una nueva variable reemplazamos las palabras por números para realizar un mejor tratamiento de la información
df_sub_clean['ORGANISMO_cat'] = df_sub_clean['ORGANISMO_DE_CUENCA'].replace({'LERMA SANTIAGO PACIFICO':0, 
                                                                 'PENINSULA DE BAJA CALIFORNIA':1,
                                                                 'PENINSULA DE YUCATAN':2, 
                                                                 'RIO BRAVO':3, 
                                                                 'CUENCAS CENTRALES DEL NORTE':4,
                                                                 'PACIFICO NORTE':5, 
                                                                 'BALSAS':6, 
                                                                 'PACIFICO SUR':7, 
                                                                 'GOLFO NORTE':8,
                                                                 'AGUAS DEL VALLE DE MEXICO':9, 
                                                                 'GOLFO CENTRO':10, 
                                                                 'FRONTERA SUR':11,
                                                                 'NOROESTE':12})

df_sub_clean['ORGANISMO_cat'] = df_sub_clean['ORGANISMO_cat'].astype(int)
df_sub_clean['ORGANISMO_cat']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1063    3
# 1064    3
# 1065    3
# 1066    3
# 1067    3
# Name: ORGANISMO_cat, Length: 1068, dtype: int32

# %%
import matplotlib.pyplot as plt
import random

number_of_colors = df_sub_clean['ORGANISMO_DE_CUENCA'].value_counts().count()

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

clean_colors_palete2 = sns.color_palette(color)
clean_colors_palete2
# Out:
# [(0.6470588235294118, 0.1568627450980392, 0.1803921568627451),
#  (0.7176470588235294, 0.2901960784313726, 0.8784313725490196),
#  (0.5254901960784314, 0.15294117647058825, 0.03137254901960784),
#  (0.37254901960784315, 0.9411764705882353, 0.1843137254901961),
#  (0.16470588235294117, 0.47058823529411764, 0.30196078431372547),
#  (0.5882352941176471, 0.12549019607843137, 0.5254901960784314),
#  (0.8627450980392157, 0.8470588235294118, 0.39215686274509803),
#  (0.6196078431372549, 0.32941176470588235, 0.9529411764705882),
#  (0.12941176470588237, 0.8196078431372549, 0.9725490196078431),
#  (0.9803921568627451, 0.4588235294117647, 0.7529411764705882),
#  (0.4823529411764706, 0.23921568627450981, 0.2823529411764706),
#  (0.1843137254901961, 0.807843137254902, 0.20392156862745098),
#  (0.06274509803921569, 0.9019607843137255, 0.043137254901960784)]

# %%
latlong2=df_sub_clean[['LATITUD','LONGITUD', 'ORGANISMO_cat']]
latlong2
# Out:
#        LATITUD   LONGITUD  ORGANISMO_cat
# 0     22.20887 -102.02210              0
# 1     21.99958 -102.20075              0
# 2     22.36685 -102.28801              0
# 3     22.18435 -102.29449              0
# 4     23.45138 -110.24480              1
# ...        ...        ...            ...
# 1063  24.76036  -99.54191              3
# 1064  24.78280  -99.70099              3
# 1065  25.55197  -99.82249              3
# 1066  24.80118 -100.32683              3
# 1067  25.09380 -100.73302              3
#
# [1068 rows x 3 columns]

# %%
#Poligonos de paises
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
world = world.set_index("iso_a3")

# %%
fig, gax = plt.subplots(figsize=(20,20))

world.query("name == 'Mexico'").plot(ax = gax, edgecolor='black', color='white')

latlong2.plot.scatter('LONGITUD','LATITUD', c='ORGANISMO_cat', cmap=ListedColormap(color), ax=gax, s=200, alpha=0.5)
latlong.plot.scatter('LONGITUD','LATITUD', c='SEMAFORO_cat', cmap=ListedColormap(clean_color_list), ax=gax)

plt.show()

gax.set_xlabel('Longitud')
gax.set_ylabel('Latitud')
gax.set_title('Clasificacion de aguas subterraneas')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

plt.show()

# %%
#debido a que la mayoría de los datos son POZO, no podríamos observar una tendencia debido a esta variable.
df_sub_clean['SUBTIPO'].value_counts()
# Out:
# POZO             1039
# MANANTIAL          12
# CENOTE              7
# POZO NORIA          4
# NORIA               3
# DESCARGA            1
# Pozo                1
# BOMBEO CENOTE       1
# Name: SUBTIPO, dtype: int64

# %%
df_sub_clean['ACUIFERO'].value_counts()
# Out:
# PENINSULA DE YUCATAN            119
# PRINCIPAL-REGION LAGUNERA        28
# ALTO ATOYAC                      19
# TEPEHUANES-SANTIAGO              16
# LA PAILA                         12
#                                ...
# CABRERA-OCAMPO                    1
# TENANCINGO                        1
# IRAPUATO-VALLE                    1
# ROSARIO-TESOPACO-EL QUIRIEGO      1
# TEPEJI DEL RIO                    1
# Name: ACUIFERO, Length: 273, dtype: int64

# %%
from sklearn import preprocessing
#hacemos un LabelEncoder para transformar palabras en numero que representa una categoría
le = preprocessing.LabelEncoder()
df_sub_clean['ACUIFERO_cat'] = le.fit_transform(df_sub_clean['ACUIFERO'])
df_sub_clean['ACUIFERO_cat'] = df_sub_clean['ACUIFERO_cat'].astype(int)
df_sub_clean['ACUIFERO_cat']
# Out:
# 0       232
# 1       232
# 2       228
# 3       228
# 4       220
#        ...
# 1063     42
# 1064     42
# 1065     41
# 1066    137
# 1067    137
# Name: ACUIFERO_cat, Length: 1068, dtype: int32

# %%
number_of_colors = df_sub_clean['ACUIFERO'].value_counts().count()

color10 = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

clean_colors_palete10 = sns.color_palette(color10)

# %%
latlong10=df_sub_clean[['LATITUD','LONGITUD', 'ACUIFERO_cat']]
latlong10
# Out:
#        LATITUD   LONGITUD  ACUIFERO_cat
# 0     22.20887 -102.02210           232
# 1     21.99958 -102.20075           232
# 2     22.36685 -102.28801           228
# 3     22.18435 -102.29449           228
# 4     23.45138 -110.24480           220
# ...        ...        ...           ...
# 1063  24.76036  -99.54191            42
# 1064  24.78280  -99.70099            42
# 1065  25.55197  -99.82249            41
# 1066  24.80118 -100.32683           137
# 1067  25.09380 -100.73302           137
#
# [1068 rows x 3 columns]

# %%
fig, gax = plt.subplots(figsize=(40,40))

world.query("name == 'Mexico'").plot(ax = gax, edgecolor='black', color='white')



latlong10.plot.scatter('LONGITUD','LATITUD', c='ACUIFERO_cat', cmap=ListedColormap(color10), ax=gax, s=200, alpha=0.5)
latlong.plot.scatter('LONGITUD','LATITUD', c='SEMAFORO_cat', cmap=ListedColormap(clean_color_list), ax=gax)

plt.show()

gax.set_xlabel('Longitud')
gax.set_ylabel('Latitud')
gax.set_title('Clasificacion de aguas subterraneas')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

plt.show()

# %%
df_sub_clean.head().T
# Out:
#                                                0                            1  \
# CLAVE                                     DLAGU6                    DLAGU6516
# SITIO                               POZO SAN GIL       POZO R013 CAÑADA HONDA
# ORGANISMO_DE_CUENCA      LERMA SANTIAGO PACIFICO      LERMA SANTIAGO PACIFICO
# ESTADO                            AGUASCALIENTES               AGUASCALIENTES
# MUNICIPIO                               ASIENTOS               AGUASCALIENTES
# ACUIFERO                      VALLE DE CHICALOTE           VALLE DE CHICALOTE
# SUBTIPO                                     POZO                         POZO
# LONGITUD                               -102.0221                   -102.20075
# LATITUD                                 22.20887                     21.99958
# ALC_mg/L                                  229.99                       231.99
# CALIDAD_ALC                                 Alta                         Alta
# CONDUCT_mS/cm                              940.0                        608.0
# CALIDAD_CONDUC             Permisible para riego             Buena para riego
# SDT_M_mg/L                                 603.6                        445.4
# CALIDAD_SDT_ra                Cultivos sensibles         Excelente para riego
# CALIDAD_SDT_salin                Potable - Dulce              Potable - Dulce
# FLUORUROS_mg/L                            0.9766                       0.9298
# CALIDAD_FLUO                    Potable - Optima             Potable - Optima
# DUR_mg/L                                 213.732                     185.0514
# CALIDAD_DUR                       Potable - Dura               Potable - Dura
# COLI_FEC_NMP/100_mL                          1.1                          1.1
# CALIDAD_COLI_FEC             Potable - Excelente          Potable - Excelente
# N_NO3_mg/L                              4.184656                      5.75011
# CALIDAD_N_NO3                Potable - Excelente      Potable - Buena calidad
# AS_TOT_mg/L                               0.0161                       0.0134
# CALIDAD_AS                        Apta como FAAP               Apta como FAAP
# CD_TOT_mg/L                                0.003                        0.003
# CALIDAD_CD                   Potable - Excelente          Potable - Excelente
# CR_TOT_mg/L                                0.005                        0.005
# CALIDAD_CR                   Potable - Excelente          Potable - Excelente
# HG_TOT_mg/L                               0.0005                       0.0005
# CALIDAD_HG                   Potable - Excelente          Potable - Excelente
# PB_TOT_mg/L                                0.005                        0.005
# CALIDAD_PB                   Potable - Excelente          Potable - Excelente
# MN_TOT_mg/L                               0.0015                       0.0015
# CALIDAD_MN                   Potable - Excelente          Potable - Excelente
# FE_TOT_mg/L                               0.0891                        0.025
# CALIDAD_FE                   Potable - Excelente          Potable - Excelente
# CONTAMINANTES                                  0                            0
# CUMPLE_CON_ALC                                SI                           SI
# CUMPLE_CON_COND                               SI                           SI
# CUMPLE_CON_SDT_ra                             SI                           SI
# CUMPLE_CON_SDT_salin                          SI                           SI
# CUMPLE_CON_FLUO                               SI                           SI
# CUMPLE_CON_DUR                                SI                           SI
# CUMPLE_CON_CF                                 SI                           SI
# CUMPLE_CON_NO3                                SI                           SI
# CUMPLE_CON_AS                                 SI                           SI
# CUMPLE_CON_CD                                 SI                           SI
# CUMPLE_CON_CR                                 SI                           SI
# CUMPLE_CON_HG                                 SI                           SI
# CUMPLE_CON_PB                                 SI                           SI
# CUMPLE_CON_MN                                 SI                           SI
# CUMPLE_CON_FE                                 SI                           SI
# SEMAFORO_cat                                   0                            0
# Coordinates           POINT (-102.0221 22.20887)  POINT (-102.20075 21.99958)
# ORGANISMO_cat                                  0                            0
# ACUIFERO_cat                                 232                          232
#
#                                                 2  \
# CLAVE                                      DLAGU7
# SITIO                                  POZO COSIO
# ORGANISMO_DE_CUENCA       LERMA SANTIAGO PACIFICO
# ESTADO                             AGUASCALIENTES
# MUNICIPIO                                   COSIO
# ACUIFERO                  VALLE DE AGUASCALIENTES
# SUBTIPO                                      POZO
# LONGITUD                               -102.28801
# LATITUD                                  22.36685
# ALC_mg/L                                   204.92
# CALIDAD_ALC                                  Alta
# CONDUCT_mS/cm                               532.0
# CALIDAD_CONDUC                   Buena para riego
# SDT_M_mg/L                                  342.0
# CALIDAD_SDT_ra               Excelente para riego
# CALIDAD_SDT_salin                 Potable - Dulce
# FLUORUROS_mg/L                             1.8045
# CALIDAD_FLUO                                 Alta
# DUR_mg/L                                  120.719
# CALIDAD_DUR                        Potable - Dura
# COLI_FEC_NMP/100_mL                           1.1
# CALIDAD_COLI_FEC              Potable - Excelente
# N_NO3_mg/L                               1.449803
# CALIDAD_N_NO3                 Potable - Excelente
# AS_TOT_mg/L                                 0.037
# CALIDAD_AS                      No apta como FAAP
# CD_TOT_mg/L                                 0.003
# CALIDAD_CD                    Potable - Excelente
# CR_TOT_mg/L                                 0.005
# CALIDAD_CR                    Potable - Excelente
# HG_TOT_mg/L                                0.0005
# CALIDAD_HG                    Potable - Excelente
# PB_TOT_mg/L                                 0.005
# CALIDAD_PB                    Potable - Excelente
# MN_TOT_mg/L                                0.0015
# CALIDAD_MN                    Potable - Excelente
# FE_TOT_mg/L                                 0.025
# CALIDAD_FE                    Potable - Excelente
# CONTAMINANTES                                   8
# CUMPLE_CON_ALC                                 SI
# CUMPLE_CON_COND                                SI
# CUMPLE_CON_SDT_ra                              SI
# CUMPLE_CON_SDT_salin                           SI
# CUMPLE_CON_FLUO                                NO
# CUMPLE_CON_DUR                                 SI
# CUMPLE_CON_CF                                  SI
# CUMPLE_CON_NO3                                 SI
# CUMPLE_CON_AS                                  NO
# CUMPLE_CON_CD                                  SI
# CUMPLE_CON_CR                                  SI
# CUMPLE_CON_HG                                  SI
# CUMPLE_CON_PB                                  SI
# CUMPLE_CON_MN                                  SI
# CUMPLE_CON_FE                                  SI
# SEMAFORO_cat                                    2
# Coordinates           POINT (-102.28801 22.36685)
# ORGANISMO_cat                                   0
# ACUIFERO_cat                                  228
#
#                                                 3  \
# CLAVE                                      DLAGU9
# SITIO                          POZO EL SALITRILLO
# ORGANISMO_DE_CUENCA       LERMA SANTIAGO PACIFICO
# ESTADO                             AGUASCALIENTES
# MUNICIPIO                         RINCON DE ROMOS
# ACUIFERO                  VALLE DE AGUASCALIENTES
# SUBTIPO                                      POZO
# LONGITUD                               -102.29449
# LATITUD                                  22.18435
# ALC_mg/L                                    327.0
# CALIDAD_ALC                                  Alta
# CONDUCT_mS/cm                               686.0
# CALIDAD_CONDUC                   Buena para riego
# SDT_M_mg/L                                  478.6
# CALIDAD_SDT_ra               Excelente para riego
# CALIDAD_SDT_salin                 Potable - Dulce
# FLUORUROS_mg/L                             1.1229
# CALIDAD_FLUO                     Potable - Optima
# DUR_mg/L                                  199.879
# CALIDAD_DUR                        Potable - Dura
# COLI_FEC_NMP/100_mL                           1.1
# CALIDAD_COLI_FEC              Potable - Excelente
# N_NO3_mg/L                               1.258597
# CALIDAD_N_NO3                 Potable - Excelente
# AS_TOT_mg/L                                0.0154
# CALIDAD_AS                         Apta como FAAP
# CD_TOT_mg/L                                 0.003
# CALIDAD_CD                    Potable - Excelente
# CR_TOT_mg/L                                 0.005
# CALIDAD_CR                    Potable - Excelente
# HG_TOT_mg/L                                0.0005
# CALIDAD_HG                    Potable - Excelente
# PB_TOT_mg/L                                 0.005
# CALIDAD_PB                    Potable - Excelente
# MN_TOT_mg/L                                0.0015
# CALIDAD_MN                    Potable - Excelente
# FE_TOT_mg/L                                 0.025
# CALIDAD_FE                    Potable - Excelente
# CONTAMINANTES                                   0
# CUMPLE_CON_ALC                                 SI
# CUMPLE_CON_COND                                SI
# CUMPLE_CON_SDT_ra                              SI
# CUMPLE_CON_SDT_salin                           SI
# CUMPLE_CON_FLUO                                SI
# CUMPLE_CON_DUR                                 SI
# CUMPLE_CON_CF                                  SI
# CUMPLE_CON_NO3                                 SI
# CUMPLE_CON_AS                                  SI
# CUMPLE_CON_CD                                  SI
# CUMPLE_CON_CR                                  SI
# CUMPLE_CON_HG                                  SI
# CUMPLE_CON_PB                                  SI
# CUMPLE_CON_MN                                  SI
# CUMPLE_CON_FE                                  SI
# SEMAFORO_cat                                    0
# Coordinates           POINT (-102.29449 22.18435)
# ORGANISMO_cat                                   0
# ACUIFERO_cat                                  228
#
#                                                  4
# CLAVE                                     DLBAJ107
# SITIO                           RANCHO EL TECOLOTE
# ORGANISMO_DE_CUENCA   PENINSULA DE BAJA CALIFORNIA
# ESTADO                         BAJA CALIFORNIA SUR
# MUNICIPIO                                   LA PAZ
# ACUIFERO                              TODOS SANTOS
# SUBTIPO                                       POZO
# LONGITUD                                 -110.2448
# LATITUD                                   23.45138
# ALC_mg/L                                   309.885
# CALIDAD_ALC                                   Alta
# CONDUCT_mS/cm                               1841.0
# CALIDAD_CONDUC               Permisible para riego
# SDT_M_mg/L                                  1179.0
# CALIDAD_SDT_ra        Cultivos con manejo especial
# CALIDAD_SDT_salin             Ligeramente salobres
# FLUORUROS_mg/L                              0.2343
# CALIDAD_FLUO                                  Baja
# DUR_mg/L                                  476.9872
# CALIDAD_DUR                         Potable - Dura
# COLI_FEC_NMP/100_mL                          291.0
# CALIDAD_COLI_FEC                         Aceptable
# N_NO3_mg/L                               15.672251
# CALIDAD_N_NO3                    No apta como FAAP
# AS_TOT_mg/L                                   0.01
# CALIDAD_AS                     Potable - Excelente
# CD_TOT_mg/L                                  0.003
# CALIDAD_CD                     Potable - Excelente
# CR_TOT_mg/L                                  0.005
# CALIDAD_CR                     Potable - Excelente
# HG_TOT_mg/L                                 0.0005
# CALIDAD_HG                     Potable - Excelente
# PB_TOT_mg/L                                  0.005
# CALIDAD_PB                     Potable - Excelente
# MN_TOT_mg/L                                 0.0015
# CALIDAD_MN                     Potable - Excelente
# FE_TOT_mg/L                                  0.025
# CALIDAD_FE                     Potable - Excelente
# CONTAMINANTES                                    4
# CUMPLE_CON_ALC                                  SI
# CUMPLE_CON_COND                                 SI
# CUMPLE_CON_SDT_ra                               SI
# CUMPLE_CON_SDT_salin                            SI
# CUMPLE_CON_FLUO                                 SI
# CUMPLE_CON_DUR                                  SI
# CUMPLE_CON_CF                                   SI
# CUMPLE_CON_NO3                                  NO
# CUMPLE_CON_AS                                   SI
# CUMPLE_CON_CD                                   SI
# CUMPLE_CON_CR                                   SI
# CUMPLE_CON_HG                                   SI
# CUMPLE_CON_PB                                   SI
# CUMPLE_CON_MN                                   SI
# CUMPLE_CON_FE                                   SI
# SEMAFORO_cat                                     2
# Coordinates             POINT (-110.2448 23.45138)
# ORGANISMO_cat                                    1
# ACUIFERO_cat                                   220

# %% [markdown]
# ##Kmeans

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Vamos a escoger el mejor número

# %%
latlong = df_sub_clean[['LATITUD','LONGITUD','CONTAMINANTES']]
Nc = range(1, 30)
kmeans = [KMeans(n_clusters=i) for i in Nc]
score = [kmeans[i].fit(latlong).score(latlong) for i in range(len(kmeans))]
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
k = 30
kmeans = KMeans(n_clusters=k, random_state=42)
mkr_dict = {0: 'o', 1: '+', 2: 'x'}

# %%
latlong3D = df_sub_clean[['LATITUD','LONGITUD', 'CONTAMINANTES']]
# Predicting the clusters
labels = kmeans.fit_predict(latlong3D)
# Getting the cluster centers
C = kmeans.cluster_centers_
 
fig = plt.figure()
#ax = Axes3D(fig, elev=-90, azim=0) #para verlo como el mapa
ax = Axes3D(fig, elev=0, azim=45) #para verlo normal

latlong3D['SEMAFORO_cat']=df_sub_clean['SEMAFORO_cat']
latlong3D['kmean_group']=labels

#para el color según k_means_group
number_of_colors3D = latlong3D['kmean_group'].nunique()

color3D = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors3D)]

color_dict=dict((i,j) for i,j in enumerate(color3D))

latlong3D['color']= latlong3D['kmean_group'].map(color_dict)

for sem, mkr in mkr_dict.items():
    d = latlong3D[latlong3D.SEMAFORO_cat==sem]
    ax.scatter(d['LATITUD'], d['LONGITUD'], d['CONTAMINANTES'], marker=mkr, c=d['color'],s=60)

ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='o', c=color3D, s=1000)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='black', s=500)

# %%
#y_pred = kmeans.fit_predict(df_sub_clean[['LONGITUD','LATITUD']])
y_pred = kmeans.fit_predict(df_sub_clean[['LONGITUD','LATITUD','SEMAFORO_cat']])
#y_pred = kmeans.fit_predict(df_sub_clean[['LONGITUD','LATITUD','ORGANISMO_cat','CONTAMINANTES']])

df_sub_clean['kmean_group'] = y_pred
#latlong = df_sub_clean[['LATITUD','LONGITUD', 'SEMAFORO_cat','kmean_group']]
latlong = df_sub_clean[['LATITUD','LONGITUD', 'SEMAFORO_cat','ORGANISMO_cat','CONTAMINANTES','kmean_group']]

latlong['marker'] = latlong['SEMAFORO_cat'].replace(mkr_dict)

# %%
fig, gax = plt.subplots(figsize=(34,34))

world.query("name == 'Mexico'").plot(ax = gax, edgecolor='black', color='white')

sem=0
#SEMAFORO_cat = 'Verde':0:'o', 'Amarillo':1:'+', 'Rojo':2:'x'
for sem, mkr in mkr_dict.items():
    d = latlong[latlong.SEMAFORO_cat==sem]
    #gax.scatter(x=d.LONGITUD, y=d.LATITUD, marker=mkr, c=d.kmean_group, cmap='tab20', s=200)
    d.plot.scatter('LONGITUD','LATITUD', marker=mkr, c=d.kmean_group, cmap=ListedColormap(color), ax=gax, s=50)
        
#para hacer los centros
gax.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c=pd.DataFrame(y_pred)[0].unique(), marker='o', s=300, alpha=0.5)
gax.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='black', marker='*', s=150, alpha=0.5)
    
gax.set_xlabel('longitude')
gax.set_ylabel('latitude')
gax.set_title('Clasificacion de aguas subterraneas')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

#gax.legend().set_visible(False)
#gax.legend_ = None
#plt.legend('',frameon=False)

#fig.legend()

#fig.legends = []

plt.show()
